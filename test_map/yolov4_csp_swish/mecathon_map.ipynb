# %%
# upload an image
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/Shareddrives/메카톤2021여름
# %cd mecathon/darknet
# Out:
# /content/gdrive/Shareddrives/메카톤2021여름
# /content/gdrive/Shareddrives/메카톤2021여름/mecathon/darknet

# %%
# !chmod +x ./darknet
# !./darknet detector map custom/obj.data custom/yolov4-csp-swish.cfg backup/yolov4-csp-swish_4000.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     64       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  64 3.775 BF
#    2 conv     32       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  32 0.419 BF
#    3 conv     64       3 x 3/ 1    320 x 320 x  32 ->  320 x 320 x  64 3.775 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  64 0.007 BF
#    5 conv    128       3 x 3/ 2    320 x 320 x  64 ->  160 x 160 x 128 3.775 BF
#    6 conv     64       1 x 1/ 1    160 x 160 x 128 ->  160 x 160 x  64 0.419 BF
#    7 route  5 		                           ->  160 x 160 x 128
# ...

# %%
# !./darknet detector map custom/obj.data custom/yolov4-csp-swish.cfg backup/yolov4-csp-swish_last.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     64       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  64 3.775 BF
#    2 conv     32       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  32 0.419 BF
#    3 conv     64       3 x 3/ 1    320 x 320 x  32 ->  320 x 320 x  64 3.775 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  64 0.007 BF
#    5 conv    128       3 x 3/ 2    320 x 320 x  64 ->  160 x 160 x 128 3.775 BF
#    6 conv     64       1 x 1/ 1    160 x 160 x 128 ->  160 x 160 x  64 0.419 BF
#    7 route  5 		                           ->  160 x 160 x 128
# ...

# %%
# !./darknet detector map custom/obj.data custom/yolov4-csp-swish.cfg backup/yolov4-csp-swish_best.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     64       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  64 3.775 BF
#    2 conv     32       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  32 0.419 BF
#    3 conv     64       3 x 3/ 1    320 x 320 x  32 ->  320 x 320 x  64 3.775 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  64 0.007 BF
#    5 conv    128       3 x 3/ 2    320 x 320 x  64 ->  160 x 160 x 128 3.775 BF
#    6 conv     64       1 x 1/ 1    160 x 160 x 128 ->  160 x 160 x  64 0.419 BF
#    7 route  5 		                           ->  160 x 160 x 128
# ...

# %%
# !./darknet detector map custom/obj.data custom/yolov4-csp-swish.cfg backup/yolov4-csp-swish_last.weights -iou_thresh 0.5
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     64       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  64 3.775 BF
#    2 conv     32       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  32 0.419 BF
#    3 conv     64       3 x 3/ 1    320 x 320 x  32 ->  320 x 320 x  64 3.775 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  64 0.007 BF
#    5 conv    128       3 x 3/ 2    320 x 320 x  64 ->  160 x 160 x 128 3.775 BF
#    6 conv     64       1 x 1/ 1    160 x 160 x 128 ->  160 x 160 x  64 0.419 BF
#    7 route  5 		                           ->  160 x 160 x 128
# ...

# %%
# !./darknet detector map custom/obj.data custom/yolov4-csp-swish.cfg backup/yolov4-csp-swish_4000.weights -iou_thresh 0.5
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     64       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  64 3.775 BF
#    2 conv     32       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  32 0.419 BF
#    3 conv     64       3 x 3/ 1    320 x 320 x  32 ->  320 x 320 x  64 3.775 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  64 0.007 BF
#    5 conv    128       3 x 3/ 2    320 x 320 x  64 ->  160 x 160 x 128 3.775 BF
#    6 conv     64       1 x 1/ 1    160 x 160 x 128 ->  160 x 160 x  64 0.419 BF
#    7 route  5 		                           ->  160 x 160 x 128
# ...

# %%
# !./darknet detector map custom/obj.data custom/yolov4-csp-swish.cfg backup/yolov4-csp-swish_best.weights -iou_thresh 0.5
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    640 x 640 x   3 ->  640 x 640 x  32 0.708 BF
#    1 conv     64       3 x 3/ 2    640 x 640 x  32 ->  320 x 320 x  64 3.775 BF
#    2 conv     32       1 x 1/ 1    320 x 320 x  64 ->  320 x 320 x  32 0.419 BF
#    3 conv     64       3 x 3/ 1    320 x 320 x  32 ->  320 x 320 x  64 3.775 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 320 x 320 x  64 0.007 BF
#    5 conv    128       3 x 3/ 2    320 x 320 x  64 ->  160 x 160 x 128 3.775 BF
#    6 conv     64       1 x 1/ 1    160 x 160 x 128 ->  160 x 160 x  64 0.419 BF
#    7 route  5 		                           ->  160 x 160 x 128
# ...

# %%
# !./darknet detector demo custom/obj.data custom/yolov4-csp-swish.cfg backup/yolov4-csp-swish_last.weights test/scooter_test1.mp4 -dont_show -out_filename test/predict_add_csp_final_test1.mp4
# !./darknet detector demo custom/obj.data custom/yolov4-csp-swish.cfg backup/yolov4-csp-swish_last.weights test/scooter_test2.mp4 -dont_show -out_filename test/predict_add_csp_final_test2.mp4
# !./darknet detector demo custom/obj.data custom/yolov4-csp-swish.cfg backup/yolov4-csp-swish_last.weights test/scooter_test3.mp4 -dont_show -out_filename test/predict_add_csp_final_test3.mp4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  cvWriteFrame
# Objects:
#
# no_helmet: 87%
#
# FPS:11.8 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 88%
#
# FPS:12.1 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 85%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 71%
# helmet: 51%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 83%
# helmet: 30%
#
# FPS:12.2 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 85%
#
# FPS:12.1 	 AVG_FPS:11.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 88%
#
# FPS:12.3 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 88%
#
# FPS:12.0 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 89%
#
# FPS:11.8 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 86%
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 86%
#
# FPS:11.6 	 AVG_FPS:11.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 76%
# helmet: 42%
#
# FPS:11.7 	 AVG_FPS:11.4
#
# ...

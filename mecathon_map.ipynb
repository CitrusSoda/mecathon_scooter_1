# %%
# upload an image
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# %cd /content/gdrive/Shareddrives/메카톤2021여름
# %cd mecathon/darknet
# Out:
# /content/gdrive/Shareddrives/메카톤2021여름
# /content/gdrive/Shareddrives/메카톤2021여름/mecathon/darknet

# %%
# !chmod +x ./darknet
# !./darknet detector map custom/obj.data custom/yolov3.cfg backup/yolov3_2000.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#    9 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   10 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#   12 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   13 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   14 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   17 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   20 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   23 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   29 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   32 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   35 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   38 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   39 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   41 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   42 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   44 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   45 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   47 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   48 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   50 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   51 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   53 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   54 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   60 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   62 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   63 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   64 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   67 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   70 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   73 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   76 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   77 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   78 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   79 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   80 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   81 conv     21       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  21 0.016 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   19 x  19 x 512
#   84 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   85 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#   86 route  85 61 	                           ->   38 x  38 x 768
#   87 conv    256       1 x 1/ 1     38 x  38 x 768 ->   38 x  38 x 256 0.568 BF
#   88 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   89 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   90 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   91 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   92 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   93 conv     21       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  21 0.031 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   38 x  38 x 256
#   96 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#   97 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#   98 route  97 36 	                           ->   76 x  76 x 384
#   99 conv    128       1 x 1/ 1     76 x  76 x 384 ->   76 x  76 x 128 0.568 BF
#  100 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  101 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  102 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  103 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  104 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  105 conv     21       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  21 0.062 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 139.512
# avg_outputs = 1104194
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov3_2000.weights...
#  seen 64, trained: 128 K-images (2 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# 232Can't open label file. (This can be normal only if you use MSCOCO): /content/gdrive/Shareddrives/메카톤2021여름/mecathon/darknet/custom/img/20210703_174900_040_saved.txt
# 308
#  detections_count = 602, unique_truth_count = 348
# class_id = 0, name = helmet, ap = 69.25%   	 (TP = 134, FP = 53)
# class_id = 1, name = no_helmet, ap = 59.91%   	 (TP = 113, FP = 59)
#
#  for conf_thresh = 0.25, precision = 0.69, recall = 0.71, F1-score = 0.70
#  for conf_thresh = 0.25, TP = 247, FP = 112, FN = 101, average IoU = 58.16 %
#
#  IoU threshold = 75 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.75) = 0.645782, or 64.58 %
# Total Detection Time: 208 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map custom/obj.data custom/yolov3.cfg backup/yolov3_3000.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#    9 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   10 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#   12 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   13 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   14 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   17 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   20 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   23 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   29 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   32 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   35 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   38 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   39 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   41 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   42 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   44 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   45 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   47 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   48 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   50 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   51 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   53 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   54 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   60 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   62 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   63 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   64 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   67 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   70 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   73 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   76 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   77 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   78 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   79 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   80 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   81 conv     21       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  21 0.016 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   19 x  19 x 512
#   84 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   85 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#   86 route  85 61 	                           ->   38 x  38 x 768
#   87 conv    256       1 x 1/ 1     38 x  38 x 768 ->   38 x  38 x 256 0.568 BF
#   88 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   89 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   90 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   91 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   92 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   93 conv     21       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  21 0.031 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   38 x  38 x 256
#   96 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#   97 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#   98 route  97 36 	                           ->   76 x  76 x 384
#   99 conv    128       1 x 1/ 1     76 x  76 x 384 ->   76 x  76 x 128 0.568 BF
#  100 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  101 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  102 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  103 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  104 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  105 conv     21       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  21 0.062 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 139.512
# avg_outputs = 1104194
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov3_3000.weights...
#  seen 64, trained: 192 K-images (3 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# 232Can't open label file. (This can be normal only if you use MSCOCO): /content/gdrive/Shareddrives/메카톤2021여름/mecathon/darknet/custom/img/20210703_174900_040_saved.txt
# 308
#  detections_count = 526, unique_truth_count = 348
# class_id = 0, name = helmet, ap = 60.68%   	 (TP = 124, FP = 56)
# class_id = 1, name = no_helmet, ap = 71.57%   	 (TP = 128, FP = 43)
#
#  for conf_thresh = 0.25, precision = 0.72, recall = 0.72, F1-score = 0.72
#  for conf_thresh = 0.25, TP = 252, FP = 99, FN = 96, average IoU = 60.77 %
#
#  IoU threshold = 75 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.75) = 0.661244, or 66.12 %
# Total Detection Time: 51 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map custom/obj.data custom/yolov3.cfg backup/yolov3_last.weights -iou_thresh 0.75
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#    9 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   10 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#   12 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   13 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   14 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   17 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   20 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   23 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   29 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   32 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   35 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   38 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   39 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   41 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   42 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   44 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   45 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   47 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   48 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   50 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   51 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   53 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   54 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   60 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   62 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   63 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   64 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   67 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   70 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   73 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   76 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   77 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   78 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   79 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   80 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   81 conv     21       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  21 0.016 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   19 x  19 x 512
#   84 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   85 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#   86 route  85 61 	                           ->   38 x  38 x 768
#   87 conv    256       1 x 1/ 1     38 x  38 x 768 ->   38 x  38 x 256 0.568 BF
#   88 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   89 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   90 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   91 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   92 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   93 conv     21       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  21 0.031 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   38 x  38 x 256
#   96 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#   97 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#   98 route  97 36 	                           ->   76 x  76 x 384
#   99 conv    128       1 x 1/ 1     76 x  76 x 384 ->   76 x  76 x 128 0.568 BF
#  100 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  101 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  102 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  103 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  104 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  105 conv     21       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  21 0.062 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 139.512
# avg_outputs = 1104194
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov3_last.weights...
#  seen 64, trained: 268 K-images (4 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# 232Can't open label file. (This can be normal only if you use MSCOCO): /content/gdrive/Shareddrives/메카톤2021여름/mecathon/darknet/custom/img/20210703_174900_040_saved.txt
# 308
#  detections_count = 490, unique_truth_count = 348
# class_id = 0, name = helmet, ap = 81.88%   	 (TP = 154, FP = 32)
# class_id = 1, name = no_helmet, ap = 81.69%   	 (TP = 141, FP = 34)
#
#  for conf_thresh = 0.25, precision = 0.82, recall = 0.85, F1-score = 0.83
#  for conf_thresh = 0.25, TP = 295, FP = 66, FN = 53, average IoU = 71.21 %
#
#  IoU threshold = 75 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.75) = 0.817867, or 81.79 %
# Total Detection Time: 52 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map custom/obj.data custom/yolov3.cfg backup/yolov3_2000.weights -iou_thresh 0.5
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#    9 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   10 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#   12 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   13 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   14 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   17 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   20 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   23 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   29 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   32 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   35 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   38 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   39 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   41 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   42 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   44 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   45 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   47 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   48 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   50 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   51 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   53 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   54 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   60 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   62 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   63 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   64 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   67 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   70 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   73 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   76 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   77 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   78 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   79 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   80 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   81 conv     21       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  21 0.016 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   19 x  19 x 512
#   84 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   85 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#   86 route  85 61 	                           ->   38 x  38 x 768
#   87 conv    256       1 x 1/ 1     38 x  38 x 768 ->   38 x  38 x 256 0.568 BF
#   88 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   89 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   90 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   91 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   92 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   93 conv     21       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  21 0.031 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   38 x  38 x 256
#   96 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#   97 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#   98 route  97 36 	                           ->   76 x  76 x 384
#   99 conv    128       1 x 1/ 1     76 x  76 x 384 ->   76 x  76 x 128 0.568 BF
#  100 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  101 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  102 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  103 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  104 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  105 conv     21       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  21 0.062 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 139.512
# avg_outputs = 1104194
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov3_2000.weights...
#  seen 64, trained: 128 K-images (2 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# 232Can't open label file. (This can be normal only if you use MSCOCO): /content/gdrive/Shareddrives/메카톤2021여름/mecathon/darknet/custom/img/20210703_174900_040_saved.txt
# 308
#  detections_count = 602, unique_truth_count = 348
# class_id = 0, name = helmet, ap = 98.31%   	 (TP = 176, FP = 11)
# class_id = 1, name = no_helmet, ap = 96.74%   	 (TP = 159, FP = 13)
#
#  for conf_thresh = 0.25, precision = 0.93, recall = 0.96, F1-score = 0.95
#  for conf_thresh = 0.25, TP = 335, FP = 24, FN = 13, average IoU = 74.82 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.975273, or 97.53 %
# Total Detection Time: 52 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map custom/obj.data custom/yolov3.cfg backup/yolov3_3000.weights -iou_thresh 0.5
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#    9 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   10 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#   12 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   13 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   14 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   17 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   20 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   23 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   29 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   32 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   35 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   38 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   39 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   41 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   42 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   44 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   45 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   47 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   48 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   50 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   51 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   53 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   54 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   60 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   62 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   63 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   64 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   67 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   70 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   73 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   76 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   77 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   78 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   79 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   80 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   81 conv     21       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  21 0.016 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   19 x  19 x 512
#   84 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   85 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#   86 route  85 61 	                           ->   38 x  38 x 768
#   87 conv    256       1 x 1/ 1     38 x  38 x 768 ->   38 x  38 x 256 0.568 BF
#   88 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   89 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   90 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   91 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   92 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   93 conv     21       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  21 0.031 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   38 x  38 x 256
#   96 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#   97 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#   98 route  97 36 	                           ->   76 x  76 x 384
#   99 conv    128       1 x 1/ 1     76 x  76 x 384 ->   76 x  76 x 128 0.568 BF
#  100 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  101 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  102 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  103 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  104 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  105 conv     21       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  21 0.062 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 139.512
# avg_outputs = 1104194
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov3_3000.weights...
#  seen 64, trained: 192 K-images (3 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# 232Can't open label file. (This can be normal only if you use MSCOCO): /content/gdrive/Shareddrives/메카톤2021여름/mecathon/darknet/custom/img/20210703_174900_040_saved.txt
# 308
#  detections_count = 526, unique_truth_count = 348
# class_id = 0, name = helmet, ap = 98.37%   	 (TP = 172, FP = 8)
# class_id = 1, name = no_helmet, ap = 95.27%   	 (TP = 158, FP = 13)
#
#  for conf_thresh = 0.25, precision = 0.94, recall = 0.95, F1-score = 0.94
#  for conf_thresh = 0.25, TP = 330, FP = 21, FN = 18, average IoU = 75.63 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.968204, or 96.82 %
# Total Detection Time: 51 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector map custom/obj.data custom/yolov3.cfg backup/yolov3_last.weights -iou_thresh 0.5
# Out:
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#    9 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   10 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#   12 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   13 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   14 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   17 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   20 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   23 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   29 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   32 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   35 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   38 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   39 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   41 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   42 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   44 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   45 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   47 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   48 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   50 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   51 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   53 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   54 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   60 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   62 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   63 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   64 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   67 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   70 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   73 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   76 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   77 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   78 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   79 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   80 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   81 conv     21       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  21 0.016 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   19 x  19 x 512
#   84 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   85 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#   86 route  85 61 	                           ->   38 x  38 x 768
#   87 conv    256       1 x 1/ 1     38 x  38 x 768 ->   38 x  38 x 256 0.568 BF
#   88 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   89 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   90 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   91 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   92 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   93 conv     21       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  21 0.031 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   38 x  38 x 256
#   96 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#   97 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#   98 route  97 36 	                           ->   76 x  76 x 384
#   99 conv    128       1 x 1/ 1     76 x  76 x 384 ->   76 x  76 x 128 0.568 BF
#  100 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  101 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  102 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  103 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  104 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  105 conv     21       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  21 0.062 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 139.512
# avg_outputs = 1104194
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov3_last.weights...
#  seen 64, trained: 268 K-images (4 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
#
#  calculation mAP (mean average precision)...
#  Detection layer: 82 - type = 28
#  Detection layer: 94 - type = 28
#  Detection layer: 106 - type = 28
# 232Can't open label file. (This can be normal only if you use MSCOCO): /content/gdrive/Shareddrives/메카톤2021여름/mecathon/darknet/custom/img/20210703_174900_040_saved.txt
# 308
#  detections_count = 490, unique_truth_count = 348
# class_id = 0, name = helmet, ap = 98.73%   	 (TP = 178, FP = 8)
# class_id = 1, name = no_helmet, ap = 97.54%   	 (TP = 163, FP = 12)
#
#  for conf_thresh = 0.25, precision = 0.94, recall = 0.98, F1-score = 0.96
#  for conf_thresh = 0.25, TP = 341, FP = 20, FN = 7, average IoU = 79.72 %
#
#  IoU threshold = 50 %, used Area-Under-Curve for each unique Recall
#  mean average precision (mAP@0.50) = 0.981336, or 98.13 %
# Total Detection Time: 51 Seconds
#
# Set -points flag:
#  `-points 101` for MS COCO
#  `-points 11` for PascalVOC 2007 (uncomment `difficult` in voc.data)
#  `-points 0` (AUC) for ImageNet, PascalVOC 2010-2012, your custom dataset

# %%
# !./darknet detector demo custom/obj.data custom/yolov3.cfg backup/yolov3_last.weights test/scooter_test1.mp4 -dont_show -out_filename test/predict_final_test1.mp4
# !./darknet detector demo custom/obj.data custom/yolov3.cfg backup/yolov3_last.weights test/scooter_test2.mp4 -dont_show -out_filename test/predict_final_test2.mp4
# !./darknet detector demo custom/obj.data custom/yolov3.cfg backup/yolov3_last.weights test/scooter_test3.mp4 -dont_show -out_filename test/predict_final_test3.mp4
# Out:
# 스트리밍 출력 내용이 길어서 마지막 5000줄이 삭제되었습니다.
#  cvWriteFrame
# Objects:
#
# no_helmet: 32%
#
# FPS:15.5 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 28%
#
# FPS:15.7 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.7 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.3 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.1 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.9 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.0 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.7 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.5 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.3 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.6 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.4 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.7 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.1 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:18.2 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 31%
#
# FPS:17.7 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 38%
#
# FPS:17.5 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 44%
#
# FPS:17.1 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 37%
#
# FPS:16.6 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 35%
#
# FPS:16.6 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 37%
#
# FPS:16.4 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 37%
#
# FPS:16.3 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 30%
#
# FPS:16.0 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.6 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.6 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.3 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.7 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:15.6 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.4 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:15.6 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 39%
#
# FPS:15.5 	 AVG_FPS:15.3
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 56%
#
# FPS:15.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 35%
#
# FPS:15.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.5 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 27%
#
# FPS:15.2 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 36%
#
# FPS:15.1 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 40%
#
# FPS:15.4 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 35%
#
# FPS:15.3 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 44%
#
# FPS:15.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 48%
#
# FPS:14.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 42%
#
# FPS:14.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 44%
#
# FPS:15.1 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 47%
#
# FPS:16.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 35%
#
# FPS:16.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 30%
#
# FPS:17.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 26%
#
# FPS:17.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.5 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 31%
#
# FPS:17.3 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 32%
#
# FPS:17.5 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 39%
#
# FPS:17.2 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 30%
#
# FPS:17.4 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.5 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 36%
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 33%
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 48%
#
# FPS:18.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 45%
#
# FPS:18.5 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 35%
#
# FPS:18.5 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 37%
#
# FPS:18.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 32%
#
# FPS:18.5 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 26%
#
# FPS:18.4 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 26%
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 33%
#
# FPS:17.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 31%
#
# FPS:18.2 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 40%
#
# FPS:17.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.3 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:17.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 44%
#
# FPS:17.2 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 56%
#
# FPS:16.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 62%
#
# FPS:16.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 51%
#
# FPS:16.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 41%
#
# FPS:17.1 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 35%
#
# FPS:18.3 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 43%
#
# FPS:18.3 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 50%
#
# FPS:18.4 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 43%
#
# FPS:18.6 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 37%
#
# FPS:18.7 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 38%
#
# FPS:18.7 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 42%
#
# FPS:18.4 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 41%
#
# FPS:18.8 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 57%
#
# FPS:19.0 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 48%
#
# FPS:19.6 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 60%
#
# FPS:18.8 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 66%
#
# FPS:18.7 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 64%
#
# FPS:18.4 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 46%
#
# FPS:18.0 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 44%
#
# FPS:17.6 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 37%
#
# FPS:17.0 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 34%
#
# FPS:16.6 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 32%
#
# FPS:17.7 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 36%
#
# FPS:17.4 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:17.3 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 48%
#
# FPS:16.8 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 61%
#
# FPS:16.6 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 55%
#
# FPS:16.2 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 50%
#
# FPS:16.5 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 51%
#
# FPS:16.9 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 63%
#
# FPS:16.4 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 60%
#
# FPS:16.2 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 56%
#
# FPS:15.6 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 31%
#
# FPS:15.6 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 40%
#
# FPS:15.5 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 39%
#
# FPS:15.4 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 41%
#
# FPS:15.1 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.0 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.2 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 27%
#
# FPS:15.8 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.0 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 25%
#
# FPS:16.1 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 26%
#
# FPS:16.1 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 26%
#
# FPS:16.8 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 25%
#
# FPS:17.2 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.2 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.3 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.6 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.0 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.0 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:16.9
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.0 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.2 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.9 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.8 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.4 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 26%
#
# FPS:17.0 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 26%
#
# FPS:17.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.2 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 27%
#
# FPS:17.3 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:16.9 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 54%
#
# FPS:16.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 46%
#
# FPS:16.5 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 37%
#
# FPS:16.5 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 26%
#
# FPS:16.3 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 27%
#
# FPS:16.2 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 28%
#
# FPS:16.1 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 42%
#
# FPS:16.1 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 36%
# helmet: 35%
#
# FPS:16.3 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 26%
# helmet: 39%
#
# FPS:16.1 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# helmet: 33%
#
# FPS:15.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 32%
# helmet: 31%
#
# FPS:15.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.7 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.3 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.1 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.3 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.1 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 36%
#
# FPS:15.1 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 50%
#
# FPS:14.8 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 48%
#
# FPS:14.9 	 AVG_FPS:16.5
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 31%
#
# FPS:14.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 49%
#
# FPS:14.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 50%
#
# FPS:15.3 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 55%
#
# FPS:15.2 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 42%
#
# FPS:15.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:14.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 59%
#
# FPS:14.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 73%
#
# FPS:15.1 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 74%
#
# FPS:15.2 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 49%
#
# FPS:16.4 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 52%
#
# FPS:16.1 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 66%
#
# FPS:16.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 63%
#
# FPS:17.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 56%
#
# FPS:17.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 55%
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 47%
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 50%
#
# FPS:18.5 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 61%
#
# FPS:18.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 56%
#
# FPS:18.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 63%
#
# FPS:17.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 72%
#
# FPS:18.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 75%
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 82%
#
# FPS:17.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 80%
#
# FPS:17.1 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 72%
#
# FPS:16.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 66%
#
# FPS:17.3 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 66%
#
# FPS:17.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 71%
#
# FPS:17.7 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 73%
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 63%
#
# FPS:17.6 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 65%
#
# FPS:18.2 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 56%
#
# FPS:17.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 66%
#
# FPS:17.8 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 64%
#
# FPS:17.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 65%
#
# FPS:17.2 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 65%
#
# FPS:17.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 64%
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 71%
#
# FPS:17.5 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 70%
#
# FPS:16.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 55%
#
# FPS:17.1 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 42%
#
# FPS:17.3 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 46%
#
# FPS:18.0 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 65%
#
# FPS:17.9 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 73%
#
# FPS:18.2 	 AVG_FPS:15.6
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 66%
#
# FPS:19.3 	 AVG_FPS:15.6
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#    9 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   10 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#   12 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   13 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   14 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   17 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   20 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   23 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   29 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   32 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   35 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   38 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   39 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   41 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   42 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   44 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   45 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   47 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   48 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   50 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   51 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   53 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   54 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   60 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   62 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   63 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   64 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   67 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   70 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   73 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   76 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   77 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   78 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   79 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   80 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   81 conv     21       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  21 0.016 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   19 x  19 x 512
#   84 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   85 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#   86 route  85 61 	                           ->   38 x  38 x 768
#   87 conv    256       1 x 1/ 1     38 x  38 x 768 ->   38 x  38 x 256 0.568 BF
#   88 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   89 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   90 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   91 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   92 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   93 conv     21       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  21 0.031 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   38 x  38 x 256
#   96 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#   97 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#   98 route  97 36 	                           ->   76 x  76 x 384
#   99 conv    128       1 x 1/ 1     76 x  76 x 384 ->   76 x  76 x 128 0.568 BF
#  100 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  101 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  102 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  103 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  104 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  105 conv     21       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  21 0.062 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 139.512
# avg_outputs = 1104194
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov3_last.weights...
#  seen 64, trained: 268 K-images (4 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# video file: test/scooter_test2.mp4
# Video stream: 1920 x 1080
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 13 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Objects:
#
#
# FPS:0.0 	 AVG_FPS:0.0
# Objects:
#
#
# FPS:2.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:3.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:4.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:6.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:7.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:8.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 28%
#
# FPS:9.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:10.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 36%
#
# FPS:11.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:11.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:12.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:13.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:14.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 39%
#
# FPS:16.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 57%
#
# FPS:18.8 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 50%
#
# FPS:18.6 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 54%
#
# FPS:18.4 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 63%
#
# FPS:18.4 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 32%
#
# FPS:18.4 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 56%
#
# FPS:18.5 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 36%
#
# FPS:18.5 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 38%
#
# FPS:18.3 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 40%
#
# FPS:18.6 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 36%
#
# FPS:18.6 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 31%
#
# FPS:18.3 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 35%
#
# FPS:18.3 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:18.4 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 28%
#
# FPS:17.9 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 39%
#
# FPS:18.2 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:17.7 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 28%
#
# FPS:17.7 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.5 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.6 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.9 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.9 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.6 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.9 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.4 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.5 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.7 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.9 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.2 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.0 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.0 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.2
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.0 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.9 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.8 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.2 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.2 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.9 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:18.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.0 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.4 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.4 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.7 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.7 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.0 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.1 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.6 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.2 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.4 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.6 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.7 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.4 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.4 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:17.9 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.3 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.4 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.7 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.7 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.7 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.6 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.8 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.6 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.1 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.0 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.0 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.0 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.0 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.3 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.7 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.5 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:18.8 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.1 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:19.5 	 AVG_FPS:18.4
#
#  cvWriteFrame
# Objects:
#
#
# FPS:20.2 	 AVG_FPS:18.4
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.
#  CUDA-version: 11000 (11020), cuDNN: 7.6.5, GPU count: 1
#  OpenCV version: 3.2.0
# Demo
#  0 : compute_capability = 600, cudnn_half = 0, GPU: Tesla P100-PCIE-16GB
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    608 x 608 x   3 ->  608 x 608 x  32 0.639 BF
#    1 conv     64       3 x 3/ 2    608 x 608 x  32 ->  304 x 304 x  64 3.407 BF
#    2 conv     32       1 x 1/ 1    304 x 304 x  64 ->  304 x 304 x  32 0.379 BF
#    3 conv     64       3 x 3/ 1    304 x 304 x  32 ->  304 x 304 x  64 3.407 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 304 x 304 x  64 0.006 BF
#    5 conv    128       3 x 3/ 2    304 x 304 x  64 ->  152 x 152 x 128 3.407 BF
#    6 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#    7 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#    8 Shortcut Layer: 5,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#    9 conv     64       1 x 1/ 1    152 x 152 x 128 ->  152 x 152 x  64 0.379 BF
#   10 conv    128       3 x 3/ 1    152 x 152 x  64 ->  152 x 152 x 128 3.407 BF
#   11 Shortcut Layer: 8,  wt = 0, wn = 0, outputs: 152 x 152 x 128 0.003 BF
#   12 conv    256       3 x 3/ 2    152 x 152 x 128 ->   76 x  76 x 256 3.407 BF
#   13 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   14 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   15 Shortcut Layer: 12,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   16 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   17 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   18 Shortcut Layer: 15,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   19 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   20 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   21 Shortcut Layer: 18,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   22 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   23 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   24 Shortcut Layer: 21,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   25 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   26 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   27 Shortcut Layer: 24,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   28 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   29 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   30 Shortcut Layer: 27,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   31 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   32 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   33 Shortcut Layer: 30,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   34 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#   35 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#   36 Shortcut Layer: 33,  wt = 0, wn = 0, outputs:  76 x  76 x 256 0.001 BF
#   37 conv    512       3 x 3/ 2     76 x  76 x 256 ->   38 x  38 x 512 3.407 BF
#   38 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   39 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   40 Shortcut Layer: 37,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   41 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   42 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   43 Shortcut Layer: 40,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   44 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   45 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   46 Shortcut Layer: 43,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   47 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   48 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   49 Shortcut Layer: 46,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   50 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   51 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   52 Shortcut Layer: 49,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   53 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   54 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   55 Shortcut Layer: 52,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   56 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   57 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   58 Shortcut Layer: 55,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   59 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   60 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   61 Shortcut Layer: 58,  wt = 0, wn = 0, outputs:  38 x  38 x 512 0.001 BF
#   62 conv   1024       3 x 3/ 2     38 x  38 x 512 ->   19 x  19 x1024 3.407 BF
#   63 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   64 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   65 Shortcut Layer: 62,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   66 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   67 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   68 Shortcut Layer: 65,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   69 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   70 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   71 Shortcut Layer: 68,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   72 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   73 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   74 Shortcut Layer: 71,  wt = 0, wn = 0, outputs:  19 x  19 x1024 0.000 BF
#   75 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   76 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   77 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   78 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   79 conv    512       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x 512 0.379 BF
#   80 conv   1024       3 x 3/ 1     19 x  19 x 512 ->   19 x  19 x1024 3.407 BF
#   81 conv     21       1 x 1/ 1     19 x  19 x1024 ->   19 x  19 x  21 0.016 BF
#   82 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   83 route  79 		                           ->   19 x  19 x 512
#   84 conv    256       1 x 1/ 1     19 x  19 x 512 ->   19 x  19 x 256 0.095 BF
#   85 upsample                 2x    19 x  19 x 256 ->   38 x  38 x 256
#   86 route  85 61 	                           ->   38 x  38 x 768
#   87 conv    256       1 x 1/ 1     38 x  38 x 768 ->   38 x  38 x 256 0.568 BF
#   88 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   89 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   90 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   91 conv    256       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x 256 0.379 BF
#   92 conv    512       3 x 3/ 1     38 x  38 x 256 ->   38 x  38 x 512 3.407 BF
#   93 conv     21       1 x 1/ 1     38 x  38 x 512 ->   38 x  38 x  21 0.031 BF
#   94 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
#   95 route  91 		                           ->   38 x  38 x 256
#   96 conv    128       1 x 1/ 1     38 x  38 x 256 ->   38 x  38 x 128 0.095 BF
#   97 upsample                 2x    38 x  38 x 128 ->   76 x  76 x 128
#   98 route  97 36 	                           ->   76 x  76 x 384
#   99 conv    128       1 x 1/ 1     76 x  76 x 384 ->   76 x  76 x 128 0.568 BF
#  100 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  101 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  102 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  103 conv    128       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x 128 0.379 BF
#  104 conv    256       3 x 3/ 1     76 x  76 x 128 ->   76 x  76 x 256 3.407 BF
#  105 conv     21       1 x 1/ 1     76 x  76 x 256 ->   76 x  76 x  21 0.062 BF
#  106 yolo
# [yolo] params: iou loss: mse (2), iou_norm: 0.75, obj_norm: 1.00, cls_norm: 1.00, delta_norm: 1.00, scale_x_y: 1.00
# Total BFLOPS 139.512
# avg_outputs = 1104194
#  Allocate additional workspace_size = 52.43 MB
# Loading weights from backup/yolov3_last.weights...
#  seen 64, trained: 268 K-images (4 Kilo-batches_64)
# Done! Loaded 107 layers from weights-file
# video file: test/scooter_test3.mp4
# Video stream: 1080 x 1920
# OpenCV: FFMPEG: tag 0x58564944/'DIVX' is not supported with codec id 13 and format 'mp4 / MP4 (MPEG-4 Part 14)'
# OpenCV: FFMPEG: fallback to use tag 0x7634706d/'mp4v'
# Objects:
#
#
# FPS:0.0 	 AVG_FPS:0.0
# Objects:
#
# no_helmet: 90%
#
# FPS:1.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 86%
#
# FPS:2.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 62%
#
# FPS:4.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 48%
#
# FPS:6.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:7.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 34%
#
# FPS:8.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
#
# FPS:9.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 30%
#
# FPS:10.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 60%
#
# FPS:10.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 88%
#
# FPS:11.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 83%
#
# FPS:11.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 89%
#
# FPS:11.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 81%
#
# FPS:11.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 67%
#
# FPS:12.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 57%
#
# FPS:13.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 71%
#
# FPS:13.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 89%
#
# FPS:13.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:13.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:13.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:13.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 90%
#
# FPS:14.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 79%
#
# FPS:14.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 77%
#
# FPS:15.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 81%
#
# FPS:15.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 77%
#
# FPS:14.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 83%
#
# FPS:15.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:15.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:15.0 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:14.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:14.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:14.7 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:15.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:14.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:14.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:14.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:14.9 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:15.2 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 92%
#
# FPS:15.4 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 67%
#
# FPS:15.5 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 76%
#
# FPS:15.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 71%
#
# FPS:15.8 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 68%
#
# FPS:15.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 72%
#
# FPS:15.3 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 71%
#
# FPS:15.1 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 51%
#
# FPS:15.6 	 AVG_FPS:0.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 54%
#
# FPS:15.5 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 77%
#
# FPS:15.3 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:15.9 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 90%
#
# FPS:15.5 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:16.2 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:15.9 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 87%
#
# FPS:16.6 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 91%
#
# FPS:16.3 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:16.1 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 87%
#
# FPS:16.8 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 82%
#
# FPS:17.2 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 80%
#
# FPS:17.3 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 72%
#
# FPS:16.9 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 84%
#
# FPS:17.4 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 85%
#
# FPS:17.0 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 81%
#
# FPS:16.4 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 45%
#
# FPS:16.1 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 73%
#
# FPS:15.9 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:15.8 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:16.3 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:16.5 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.3 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:15.9 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:15.5 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:15.0 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:15.2 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:15.9 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:15.5 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:15.4 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 89%
#
# FPS:14.9 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 88%
#
# FPS:14.7 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 75%
#
# FPS:14.6 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 75%
#
# FPS:14.8 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 66%
#
# FPS:15.1 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 85%
#
# FPS:15.5 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 95%
#
# FPS:15.7 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 95%
#
# FPS:15.9 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 88%
#
# FPS:16.2 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 95%
#
# FPS:16.2 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.1 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.2 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 80%
#
# FPS:16.4 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:16.6 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 95%
#
# FPS:16.8 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:16.9 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:17.0 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:17.2 	 AVG_FPS:15.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 95%
#
# FPS:17.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:16.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 88%
#
# FPS:16.0 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 91%
#
# FPS:16.0 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:15.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 95%
#
# FPS:15.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:15.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:15.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 89%
#
# FPS:15.0 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 92%
#
# FPS:15.2 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:15.7 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:15.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 100%
#
# FPS:15.0 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 100%
#
# FPS:14.6 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:14.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:14.7 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:14.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:14.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:14.6 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:14.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 86%
#
# FPS:14.0 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 72%
#
# FPS:13.7 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 91%
#
# FPS:13.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:13.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 92%
#
# FPS:14.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:14.7 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:14.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:15.0 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 90%
#
# FPS:15.2 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:15.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:15.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:15.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 95%
#
# FPS:15.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:15.6 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:15.6 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 91%
#
# FPS:15.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:15.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:15.1 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:15.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:16.0 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:16.7 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:16.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 95%
#
# FPS:17.1 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:16.8 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:17.1 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.4 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.6 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.3 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.2 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:16.1 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 91%
#
# FPS:15.7 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:15.6 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:15.4 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:15.2 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:15.1 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:15.3 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 99%
#
# FPS:15.2 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:15.1 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 85%
#
# FPS:15.2 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 88%
#
# FPS:15.2 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:15.2 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 95%
#
# FPS:15.3 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:15.0 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:15.1 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 97%
#
# FPS:15.1 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 96%
#
# FPS:15.2 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 93%
#
# FPS:15.5 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 79%
#
# FPS:15.3 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 90%
#
# FPS:15.7 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:15.6 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.5 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 98%
#
# FPS:16.6 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:16.3 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 77%
#
# FPS:15.9 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 89%
#
# FPS:15.9 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:16.4 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 85%
#
# FPS:16.0 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 81%
#
# FPS:16.3 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 64%
#
# FPS:16.2 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 86%
#
# FPS:15.7 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 89%
#
# FPS:16.5 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 94%
#
# FPS:16.6 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 86%
#
# FPS:17.3 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 50%
#
# FPS:17.6 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 81%
#
# FPS:17.7 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 87%
#
# FPS:17.5 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 84%
#
# FPS:18.1 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 86%
#
# FPS:18.0 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 32%
#
# FPS:18.6 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 38%
#
# FPS:18.4 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 73%
#
# FPS:17.7 	 AVG_FPS:14.4
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 73%
#
# FPS:17.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 45%
#
# FPS:17.2 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 54%
#
# FPS:16.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 37%
#
# FPS:16.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 34%
#
# FPS:16.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 65%
#
# FPS:17.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 53%
#
# FPS:17.7 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 67%
#
# FPS:17.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 56%
#
# FPS:17.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 45%
#
# FPS:17.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 45%
#
# FPS:16.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 58%
#
# FPS:16.6 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 48%
#
# FPS:16.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 34%
#
# FPS:15.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 31%
#
# FPS:15.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 34%
#
# FPS:15.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 29%
#
# FPS:15.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.2 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:16.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 66%
#
# FPS:16.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 74%
#
# FPS:17.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 74%
#
# FPS:17.7 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 74%
#
# FPS:17.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 81%
#
# FPS:17.7 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 50%
#
# FPS:17.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 52%
#
# FPS:17.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 47%
#
# FPS:17.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 46%
#
# FPS:17.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 64%
#
# FPS:17.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 85%
#
# FPS:17.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 92%
#
# FPS:17.2 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 85%
#
# FPS:17.0 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 74%
#
# FPS:16.8 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 62%
#
# FPS:17.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 64%
#
# FPS:16.7 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 58%
#
# FPS:16.6 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 58%
#
# FPS:16.2 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 41%
#
# FPS:16.1 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 36%
#
# FPS:15.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
#
# FPS:15.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 35%
#
# FPS:16.3 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 48%
#
# FPS:16.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 43%
#
# FPS:17.6 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 39%
#
# FPS:18.0 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 51%
#
# FPS:17.5 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 58%
#
# FPS:17.4 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 67%
#
# FPS:16.9 	 AVG_FPS:15.7
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 61%
#
# FPS:16.6 	 AVG_FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 57%
#
# FPS:16.5 	 AVG_FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 40%
#
# FPS:16.0 	 AVG_FPS:16.0
#
#  cvWriteFrame
# Objects:
#
# no_helmet: 56%
#
# FPS:16.2 	 AVG_FPS:16.0
# Stream closed.
#
#  cvWriteFrame
# input video stream closed.
#  closing... closed!output_video_writer closed.
